# %%
# %%capture
# !pip install box2d-py

# %%
import os
import cv2
import gym
import time
import collections

import numpy as np
import torch as T
import torch.optim as optim
import torch.nn as nn
import torch.nn.functional as F
import matplotlib.pyplot as plt

from tqdm.notebook import tqdm

# %matplotlib inline

# %%
T.cuda.get_device_name()
# Out:
# 'Tesla T4'

# %% [markdown]
# ## **OU Noise**

# %%
class OUActionNoise:
    def __init__(self, mu, sigma=0.15, theta=0.2, dt=1e-2, x0=None):
        self.mu = mu
        self.sigma = sigma
        self.theta = theta
        self.dt = dt
        self.x0 = x0
        self.x_prev = None
        self.reset()

    def __call__(self):
        x = self.x_prev + (self.theta * (self.mu - self.x_prev) * self.dt) +    \
            (self.sigma * np.sqrt(self.dt) * np.random.normal(size=self.mu.shape))
        self.x_prev = x
        return x

    def reset(self):
        self.x_prev = self.x0 if self.x0 is not None else np.zeros_like(self.mu)

# %% [markdown]
# ## **Replay Buffer**

# %%
class ReplayBuffer:
    def __init__(self, mem_size, observation_shape, n_actions):
        self.mem_size = mem_size
        self.mem_counter = 0
        # DATA
        self.states = np.zeros((mem_size, *observation_shape), dtype=np.float32)
        self.actions = np.zeros((mem_size , n_actions), dtype=np.float32)
        self.rewards = np.zeros(mem_size, dtype=np.float32)
        self.states_ = np.zeros((mem_size, *observation_shape), dtype=np.float32)
        self.terminals = np.zeros(mem_size, dtype=bool)

    # STORE TRANSITIONS IN BUFFER
    def store_transition(self, state, action, reward, state_, done):
        index = self.mem_counter % self.mem_size
        self.states[index] = state
        self.actions[index] = action
        self.rewards[index] = reward
        self.states_[index] = state_
        self.terminals[index] = done # 1 if 'done' else 0
        self.mem_counter += 1

    # UNIFORMLY SAMPLES 'BUFFER' AND RETURNS A 'BATCH' OF batch_size
    def sample_batch(self, batch_size):
        max_index = min(self.mem_counter, self.mem_size)
        batch_indices = np.random.choice(max_index, batch_size, replace=False)
        states = self.states[batch_indices]
        actions = self.actions[batch_indices]
        rewards = self.rewards[batch_indices]
        states_ = self.states_[batch_indices]
        terminals = self.terminals[batch_indices]
        return (states, actions, rewards, states_, terminals)

# %% [markdown]
# ## **Networks**

# %%
class ActorNetwork(nn.Module):
    def __init__(self, lr, observation_shape, fc1_size, fc2_size, n_actions, model_name, model_dir):
        super().__init__()
        self.model_dir = model_dir
        self.model_file = os.path.join(self.model_dir, model_name+'_ACTOR')
        # ANN
        self.fc1 = nn.Linear(observation_shape[0], fc1_size)
        self.ln1 = nn.LayerNorm(fc1_size)
        self.fc2 = nn.Linear(fc1_size, fc2_size)
        self.ln2 = nn.LayerNorm(fc2_size)
        self.out = nn.Linear(fc2_size, n_actions)
        # FAN INS & WEIGHT INIT
        f1 = 1/(np.sqrt(self.fc1.weight.data.size()[0])) 
        self.fc1.weight.data.uniform_(-f1,f1)
        self.fc1.bias.data.uniform_(-f1,f1)
        f2 = 1/(np.sqrt(self.fc2.weight.data.size()[0])) 
        self.fc2.weight.data.uniform_(-f2,f2)
        self.fc2.bias.data.uniform_(-f2,f2)
        fo = 0.003
        self.out.weight.data.uniform_(-fo,fo)
        self.out.bias.data.uniform_(-fo,fo)            
        # UTILS
        self.device = T.device('cuda:0' if T.cuda.is_available() else 'cpu')
        self.optimizer = optim.Adam(self.parameters(), lr=lr)
        self.to(self.device)

    def forward(self, state):
        mu = self.ln1(self.fc1(state))
        mu = F.relu(mu)
        mu = self.ln2(self.fc2(mu))
        mu = F.relu(mu)
        mu = self.out(mu)
        mu = F.tanh(mu)
        return mu #mu = a

    def save_model(self):
        print("[INFO] ACTOR - Saving model")
        checkpoint = {
            'model_state_dict': self.state_dict(),
            'optimizer_state_dict' : self.optimizer.state_dict()
        }
        T.save(checkpoint, self.model_file)
    
    def load_model(self, cpu=False):
        print("[INFO] ACTOR - Loading model")
        
        map_location = T.device('cpu') if (cpu) else None
        
        checkpoint = T.load(self.model_file, map_location=map_location)
        self.load_state_dict(checkpoint['model_state_dict'])
        self.optimizer.load_state_dict(checkpoint['optimizer_state_dict'])

# %%
class CriticNetwork(nn.Module):
    def __init__(self, lr, observation_shape, fc1_size, fc2_size, n_actions, model_name, model_dir):
        super().__init__()
        self.model_dir = model_dir
        self.model_file = os.path.join(self.model_dir, model_name+'_CRITIC')
        # ANN
        self.fc1 = nn.Linear(observation_shape[0], fc1_size)
        self.ln1 = nn.LayerNorm(fc1_size)
        self.fc2 = nn.Linear(fc1_size, fc2_size)
        self.ln2 = nn.LayerNorm(fc2_size)
        self.fcA = nn.Linear(n_actions, fc2_size)
        self.out = nn.Linear(fc2_size, 1)
        # FAN INS & WEIGHT INIT 
        f1 = 1/(np.sqrt(self.fc1.weight.data.size()[0])) 
        self.fc1.weight.data.uniform_(-f1,f1)
        self.fc1.bias.data.uniform_(-f1,f1)
        f2 = 1/(np.sqrt(self.fc2.weight.data.size()[0])) 
        self.fc2.weight.data.uniform_(-f2,f2)
        self.fc2.bias.data.uniform_(-f2,f2)
        fA = 1/(np.sqrt(self.fcA.weight.data.size()[0]))
        self.fcA.weight.data.uniform_(-fA,fA)
        self.fcA.bias.data.uniform_(-fA,fA)
        fo = 0.003
        self.out.weight.data.uniform_(-fo,fo)
        self.out.bias.data.uniform_(-fo,fo)
        # UTILS
        self.device = T.device('cuda:0' if T.cuda.is_available() else 'cpu')
        self.optimizer = optim.Adam(self.parameters(), lr=lr, weight_decay=0.01)
        self.to(self.device)

    def forward(self, state, action):
        s = self.ln1(self.fc1(state))
        s = F.relu(s)
        s = self.ln2(self.fc2(s))
        a = self.fcA(action)
        q = T.add(s, a)
        q = F.relu(q)
        q = self.out(q)
        return q

    def save_model(self):
        print("[INFO] CRITIC - Saving model")
        checkpoint = {
            'model_state_dict': self.state_dict(),
            'optimizer_state_dict' : self.optimizer.state_dict()
        }
        T.save(checkpoint, self.model_file)
    
    def load_model(self, cpu=False):
        print("[INFO] CRITIC - Loading model")
        
        map_location = T.device('cpu') if (cpu) else None
        
        checkpoint = T.load(self.model_file, map_location=map_location)
        self.load_state_dict(checkpoint['model_state_dict'])
        self.optimizer.load_state_dict(checkpoint['optimizer_state_dict'])

# %% [markdown]
# ## **Agent**

# %%
class DDPGAgent:
    def __init__(self, observation_shape, n_actions, actor_lr, critic_lr, fc1_size, fc2_size, tau, gamma, 
                 mem_size, batch_size, algo_name, env_name, model_dir):
        self.observation_shape = observation_shape
        self.n_actions = n_actions
        self.A_LR = actor_lr
        self.C_LR = critic_lr
        self.TAU = tau
        self.GAMMA = gamma
        self.noise = OUActionNoise(mu=np.zeros(n_actions))

        # MEM PARAMS
        self.mem_size = mem_size
        self.batch_size = batch_size
        self.memory = ReplayBuffer(mem_size, observation_shape, n_actions)

        # MODEL PARAMS
        self.algo_name = algo_name
        self.env_name = env_name
        self.model_dir = model_dir
        # A1
        self.A_STEP = ActorNetwork(actor_lr, observation_shape, fc1_size, fc2_size, n_actions,
                              model_name = env_name+'_'+algo_name+'_STEP',
                              model_dir = model_dir)
        # A2
        self.A_TARGET = ActorNetwork(actor_lr, observation_shape, fc1_size, fc2_size, n_actions,
                              model_name = env_name+'_'+algo_name+'_TARGET',
                              model_dir = model_dir)
        # C1
        self.C_STEP = CriticNetwork(critic_lr, observation_shape, fc1_size, fc2_size, n_actions,
                              model_name = env_name+'_'+algo_name+'_STEP',
                              model_dir = model_dir)
        # C2
        self.C_TARGET = CriticNetwork(critic_lr, observation_shape, fc1_size, fc2_size, n_actions,
                              model_name = env_name+'_'+algo_name+'_TARGET',
                              model_dir = model_dir)
        self.update_target_networks(tau=1) # HARD UPDATE ON INIT
    
    def get_action(self, observation):
        self.A_STEP.eval()
        # OBSERVATION TO TENSOR
        observation = T.tensor(observation, dtype=T.float32).to(self.A_STEP.device)
        state = T.unsqueeze(observation, 0)                                     # T.tensor([array]) = T.unsqueeze(T.tensor(array), 0)
        # GET mu = A1(s)
        mu = self.A_STEP(state)
        mu_PRIME = mu + (T.tensor(self.noise(), dtype=T.float32).to(self.A_STEP.device)) # SHAPE (1,4) + (4)
        self.A_STEP.train()
        
        return mu_PRIME.cpu().detach().numpy()[0]

    def learn(self):
        if (self.memory.mem_counter < self.batch_size): return # return if insufficient samples present
        states, actions, rewards, states_, terminals = self.sample_batch()

        # CALC  Q1 = C1(s, a)
        q1_preds = self.C_STEP(states, actions)
        # CALC  Q2 = y' = R + gamma*(C2(s_, a2_)) where a2_ = A2(s_)
        a2_ = self.A_TARGET(states_)
        q2_next = self.C_TARGET(states_, a2_)
        q2_next[terminals] = 0.0
        q2_next = q2_next.view(-1)
        q2_targets = rewards + (self.GAMMA * q2_next)
        q2_targets = q2_targets.view(self.batch_size, 1)

        # CRITIC LOSS
        critic_loss = F.mse_loss(q1_preds, q2_targets)
        self.C_STEP.optimizer.zero_grad()
        critic_loss.backward()
        self.C_STEP.optimizer.step()
        # ACTOR LOSS
        actor_loss = -(self.C_STEP(states, self.A_STEP(states)))
        actor_loss = T.mean(actor_loss)
        self.A_STEP.optimizer.zero_grad()
        actor_loss.backward()
        self.A_STEP.optimizer.step()
        # UPDATE WEIGHTS OF TARGET NETWORK
        self.update_target_networks()

    def update_target_networks(self, tau=None):
        TAU = self.TAU if tau is None else tau

        A1_state_dict =  dict(self.A_STEP.named_parameters())
        C1_state_dict =  dict(self.C_STEP.named_parameters())
        A2_state_dict =  dict(self.A_TARGET.named_parameters())
        C2_state_dict =  dict(self.C_TARGET.named_parameters())
        # SOFT UPDATE
        for name in A1_state_dict:
            A1_state_dict[name] = (TAU *  A1_state_dict[name].clone()) + ((1-TAU)* A2_state_dict[name].clone())
        for name in C1_state_dict:
            C1_state_dict[name] = (TAU *  C1_state_dict[name].clone()) + ((1-TAU)* C2_state_dict[name].clone())
        # UPDATE TARGET WEIGHTS
        self.A_TARGET.load_state_dict(A1_state_dict)
        self.C_TARGET.load_state_dict(C1_state_dict)

        

    def store_transition(self, state, action, reward, state_, done):
        self.memory.store_transition(state, action, reward, state_, done)

    def sample_batch(self):
        states, actions, rewards, states_, terminals = self.memory.sample_batch(self.batch_size)
        states = T.tensor(states).to(self.A_STEP.device)
        actions = T.tensor(actions).to(self.A_STEP.device)
        rewards = T.tensor(rewards).to(self.A_STEP.device)
        states_ = T.tensor(states_).to(self.A_STEP.device)
        terminals = T.tensor(terminals).to(self.A_STEP.device)
        return states, actions, rewards, states_, terminals    

    def save_models(self):
        self.A_STEP.save_model()
        self.A_TARGET.save_model()
        self.C_STEP.save_model()
        self.C_TARGET.save_model()

    def load_models(self, cpu=False):
        self.A_STEP.load_model(cpu)
        self.A_TARGET.load_model(cpu)
        self.C_STEP.load_model(cpu)
        self.C_TARGET.load_model(cpu)

# %% [markdown]
# ## **Training**

# %%
env_name = "LunarLanderContinuous-v2"
env = gym.make(env_name)

N_EPISODES = 1000

# %%
agent = DDPGAgent(observation_shape=env.observation_space.shape,
                  n_actions=env.action_space.shape[0],
                  actor_lr=1e-4,
                  critic_lr=1e-3,
                  fc1_size=400,
                  fc2_size=300,
                  tau=0.001,
                  gamma=0.99,
                  mem_size=100000,
                  batch_size=64,
                  algo_name='DDPG',
                  env_name=env_name,
                  model_dir='./')

# %%
episode_rewards, episode_lengths, mean_rewards = [],[],[]
best_reward = -np.inf

for episode_n in tqdm(range(N_EPISODES)):
    total_reward, total_moves = 0,0

    done = False
    agent.noise.reset()
    observation = env.reset()

    while not done:
        action = agent.get_action(observation)
        observation_, reward, done, _ = env.step(action)

        total_reward += reward
        total_moves += 1

        # STORE DATA & LEARN
        agent.store_transition(observation, action, reward, observation_, done)
        agent.learn()

        observation = observation_
    
    episode_rewards.append(total_reward)
    episode_lengths.append(total_moves)
    
    mean_reward = np.mean(episode_rewards[-100:])
    mean_rewards.append(mean_reward)
    if(mean_reward > best_reward):
        agent.save_models()
        best_reward = mean_reward
    
    print("ITER: ",episode_n,"\tRWD: ",round(total_reward,2),"\tM_RWD: ",round(mean_reward,2),"\tLEN: ",total_moves)
# Out:
# HBox(children=(FloatProgress(value=0.0, max=1000.0), HTML(value='')))
# /usr/local/lib/python3.6/dist-packages/torch/nn/functional.py:1614: UserWarning: nn.functional.tanh is deprecated. Use torch.tanh instead.
#   warnings.warn("nn.functional.tanh is deprecated. Use torch.tanh instead.")
# [INFO] ACTOR - Saving model
# [INFO] ACTOR - Saving model
# [INFO] CRITIC - Saving model
# [INFO] CRITIC - Saving model
# ITER:  0 	RWD:  -448.57 	M_RWD:  -448.57 	LEN:  203
# ITER:  1 	RWD:  -1397.77 	M_RWD:  -923.17 	LEN:  118
# ITER:  2 	RWD:  -339.07 	M_RWD:  -728.47 	LEN:  50
# ITER:  3 	RWD:  -219.08 	M_RWD:  -601.12 	LEN:  62
# ITER:  4 	RWD:  -790.99 	M_RWD:  -639.1 	LEN:  70
# ITER:  5 	RWD:  -1177.87 	M_RWD:  -728.89 	LEN:  95
	LEN:  1000
# [INFO] ACTOR - Saving model
# [INFO] ACTOR - Saving model
# [INFO] CRITIC - Saving model
# [INFO] CRITIC - Saving model
# ITER:  263 	RWD:  -32.95 	M_RWD:  -57.14 	LEN:  1000
# ITER:  264 	RWD:  -43.55 	M_RWD:  -57.56 	LEN:  1000
# ITER:  265 	RWD:  -230.9 	M_RWD:  -59.44 	LEN:  332
# ITER:  266 	RWD:  -28.52 	M_RWD:  -59.51 	LEN:  1000
# ITER:  267 	RWD:  -38.03 	M_RWD:  -58.23 	LEN:  1000
# ITER:  268 	RWD:  -95.2 	M_RWD:  -58.31 	LEN:  244
# ITER:  269 	RWD:  -35.15 	M_RWD:  -58.08 	LEN:  1000
# ITER:  270 	RWD:  -33.77 	M_RWD:  -57.91 	LEN:  1000
# ITER:  271 	RWD:  32.71 	M_RWD:  -57.33 	LEN:  92
# [INFO] ACTOR - Saving model
# [INFO] ACTOR - Saving model
# [INFO] CRITIC - Saving model
# [INFO] CRITIC - Saving model
# ITER:  272 	RWD:  -0.83 	M_RWD:  -56.14 	LEN:  1000
# [INFO] ACTOR - Saving model
# [INFO] ACTOR - Saving model
# [INFO] CRITIC - Saving model
# [INFO] CRITIC - Saving model
# ITER:  273 	RWD:  -72.42 	M_RWD:  -54.93 	LEN:  1000
# ITER:  274 	RWD:  -119.62 	M_RWD:  -55.7 	LEN:  945
# [INFO] ACTOR - Saving model
# [INFO] ACTOR - Saving model
# [INFO] CRITIC - Saving model
# [INFO] CRITIC - Saving model
# ITER:  275 	RWD:  -11.82 	M_RWD:  -54.35 	LEN:  1000
# [INFO] ACTOR - Saving model
# [INFO] ACTOR - Saving model
# [INFO] CRITIC - Saving model
# [INFO] CRITIC - Saving model
# ITER:  276 	RWD:  -4.26 	M_RWD:  -53.36 	LEN:  1000
# [INFO] ACTOR - Saving model
# [INFO] ACTOR - Saving model
# [INFO] CRITIC - Saving model
# [INFO] CRITIC - Saving model
# ITER:  277 	RWD:  -22.57 	M_RWD:  -51.65 	LEN:  1000
# ITER:  278 	RWD:  -60.71 	M_RWD:  -52.12 	LEN:  1000
# ITER:  279 	RWD:  -15.53 	M_RWD:  -51.91 	LEN:  1000
# [INFO] ACTOR - Saving model
# [INFO] ACTOR - Saving model
# [INFO] CRITIC - Saving model
# [INFO] CRITIC - Saving model
# ITER:  280 	RWD:  -54.39 	M_RWD:  -51.01 	LEN:  1000
# [INFO] ACTOR - Saving model
# [INFO] ACTOR - Saving model
# [INFO] CRITIC - Saving model
# [INFO] CRITIC - Saving model
# ITER:  281 	RWD:  -32.2 	M_RWD:  -50.34 	LEN:  1000
# [INFO] ACTOR - Saving model
# [INFO] ACTOR - Saving model
# [INFO] CRITIC - Saving model
# [INFO] CRITIC - Saving model
# ITER:  282 	RWD:  13.14 	M_RWD:  -49.04 	LEN:  1000
# [INFO] ACTOR - Saving model
# [INFO] ACTOR - Saving model
# [INFO] CRITIC - Saving model
# [INFO] CRITIC - Saving model
# ITER:  283 	RWD:  -32.98 	M_RWD:  -48.39 	LEN:  1000
# ITER:  284 	RWD:  -112.0 	M_RWD:  -49.11 	LEN:  55
# [INFO] ACTOR - Saving model
# [INFO] ACTOR - Saving model
# [INFO] CRITIC - Saving model
# [INFO] CRITIC - Saving model
# ITER:  285 	RWD:  -60.96 	M_RWD:  -48.15 	LEN:  1000
# [INFO] ACTOR - Saving model
# [INFO] ACTOR - Saving model
# [INFO] CRITIC - Saving model
# [INFO] CRITIC - Saving model
# ITER:  286 	RWD:  0.39 	M_RWD:  -47.24 	LEN:  1000
# ITER:  287 	RWD:  9.57 	M_RWD:  -47.32 	LEN:  1000
# [INFO] ACTOR - Saving model
# [INFO] ACTOR - Saving model
# [INFO] CRITIC - Saving model
# [INFO] CRITIC - Saving model
# ITER:  288 	RWD:  -22.1 	M_RWD:  -47.07 	LEN:  1000
# [INFO] ACTOR - Saving model
# [INFO] ACTOR - Saving model
# [INFO] CRITIC - Saving model
# [INFO] CRITIC - Saving model
# ITER:  289 	RWD:  137.73 	M_RWD:  -45.69 	LEN:  784
# ITER:  290 	RWD:  -83.51 	M_RWD:  -46.72 	LEN:  1000
# ITER:  291 	RWD:  -16.33 	M_RWD:  -46.62 	LEN:  1000
# [INFO] ACTOR - Saving model
# [INFO] ACTOR - Saving model
# [INFO] CRITIC - Saving model
# [INFO] CRITIC - Saving model
# ITER:  292 	RWD:  38.98 	M_RWD:  -44.98 	LEN:  1000
# ITER:  293 	RWD:  -39.45 	M_RWD:  -45.45 	LEN:  1000
# ITER:  294 	RWD:  -112.87 	M_RWD:  -46.29 	LEN:  85
# [INFO] ACTOR - Saving model
# [INFO] ACTOR - Saving model
# [INFO] CRITIC - Saving model
# [INFO] CRITIC - Saving model
# ITER:  295 	RWD:  198.53 	M_RWD:  -42.68 	LEN:  347
# [INFO] ACTOR - Saving model
# [INFO] ACTOR - Saving model
# [INFO] CRITIC - Saving model
# [INFO] CRITIC - Saving model
# ITER:  296 	RWD:  -217.14 	M_RWD:  -42.06 	LEN:  70
# [INFO] ACTOR - Saving model
# [INFO] ACTOR - Saving model
# [INFO] CRITIC - Saving model
# [INFO] CRITIC - Saving model
# ITER:  297 	RWD:  -90.76 	M_RWD:  -41.72 	LEN:  135
# [INFO] ACTOR - Saving model
# [INFO] ACTOR - Saving model
# [INFO] CRITIC - Saving model
# [INFO] CRITIC - Saving model
# ITER:  298 	RWD:  -35.58 	M_RWD:  -40.99 	LEN:  1000
# [INFO] ACTOR - Saving model
# [INFO] ACTOR - Saving model
# [INFO] CRITIC - Saving model
# [INFO] CRITIC - Saving model
# ITER:  299 	RWD:  121.34 	M_RWD:  -38.54 	LEN:  912
# [INFO] ACTOR - Saving model
# [INFO] ACTOR - Saving model
# [INFO] CRITIC - Saving model
# [INFO] CRITIC - Saving model
# ITER:  300 	RWD:  -41.78 	M_RWD:  -38.3 	LEN:  408
# [INFO] ACTOR - Saving model
# [INFO] ACTOR - Saving model
# [INFO] CRITIC - Saving model
# [INFO] CRITIC - Saving model
# ITER:  301 	RWD:  180.68 	M_RWD:  -36.1 	LEN:  344
# [INFO] ACTOR - Saving model
# [INFO] ACTOR - Saving model
# [INFO] CRITIC - Saving model
# [INFO] CRITIC - Saving model
# ITER:  302 	RWD:  42.93 	M_RWD:  -33.86 	LEN:  843
# [INFO] ACTOR - Saving model
# [INFO] ACTOR - Saving model
# [INFO] CRITIC - Saving model
# [INFO] CRITIC - Saving model
# ITER:  303 	RWD:  66.69 	M_RWD:  -33.01 	LEN:  1000
# [INFO] ACTOR - Saving model
# [INFO] ACTOR - Saving model
# [INFO] CRITIC - Saving model
# [INFO] CRITIC - Saving model
# ITER:  304 	RWD:  -83.09 	M_RWD:  -29.6 	LEN:  1000
# ITER:  305 	RWD:  -34.79 	M_RWD:  -29.6 	LEN:  1000
# [INFO] ACTOR - Saving model
# [INFO] ACTOR - Saving model
# [INFO] CRITIC - Saving model
# [INFO] CRITIC - Saving model
# ITER:  306 	RWD:  29.2 	M_RWD:  -29.33 	LEN:  203
# [INFO] ACTOR - Saving model
# [INFO] ACTOR - Saving model
# [INFO] CRITIC - Saving model
# [INFO] CRITIC - Saving model
# ITER:  307 	RWD:  -43.97 	M_RWD:  -29.12 	LEN:  1000
# [INFO] ACTOR - Saving model
# [INFO] ACTOR - Saving model
# [INFO] CRITIC - Saving model
# [INFO] CRITIC - Saving model
# ITER:  308 	RWD:  148.29 	M_RWD:  -26.19 	LEN:  322
# [INFO] ACTOR - Saving model
# [INFO] ACTOR - Saving model
# [INFO] CRITIC - Saving model
# [INFO] CRITIC - Saving model
# ITER:  309 	RWD:  161.41 	M_RWD:  -24.29 	LEN:  946
# [INFO] ACTOR - Saving model
# [INFO] ACTOR - Saving model
# [INFO] CRITIC - Saving model
# [INFO] CRITIC - Saving model
# ITER:  310 	RWD:  97.08 	M_RWD:  -22.92 	LEN:  766
# [INFO] ACTOR - Saving model
# [INFO] ACTOR - Saving model
# [INFO] CRITIC - Saving model
# [INFO] CRITIC - Saving model
# ITER:  311 	RWD:  42.91 	M_RWD:  -22.21 	LEN:  172
# ITER:  312 	RWD:  -57.16 	M_RWD:  -22.9 	LEN:  88
# ITER:  313 	RWD:  -100.86 	M_RWD:  -23.72 	LEN:  263
# ITER:  314 	RWD:  -29.88 	M_RWD:  -23.76 	LEN:  238
# [INFO] ACTOR - Saving model
# [INFO] ACTOR - Saving model
# [INFO] CRITIC - Saving model
# [INFO] CRITIC - Saving model
# ITER:  315 	RWD:  211.97 	M_RWD:  -21.39 	LEN:  210
# ITER:  316 	RWD:  -66.55 	M_RWD:  -22.13 	LEN:  263
# ITER:  317 	RWD:  -102.42 	M_RWD:  -22.98 	LEN:  306
# ITER:  318 	RWD:  -7.42 	M_RWD:  -22.66 	LEN:  158
# ITER:  319 	RWD:  -66.21 	M_RWD:  -22.73 	LEN:  229
# ITER:  320 	RWD:  -56.7 	M_RWD:  -23.24 	LEN:  212
# ITER:  321 	RWD:  -45.88 	M_RWD:  -23.0 	LEN:  279
# ITER:  322 	RWD:  -63.59 	M_RWD:  -23.88 	LEN:  204
# ITER:  323 	RWD:  -61.26 	M_RWD:  -24.02 	LEN:  233
# ITER:  324 	RWD:  -95.95 	M_RWD:  -25.1 	LEN:  1000
# ITER:  325 	RWD:  -158.35 	M_RWD:  -26.39 	LEN:  265
# ITER:  326 	RWD:  165.55 	M_RWD:  -24.12 	LEN:  367
# ITER:  327 	RWD:  -55.65 	M_RWD:  -24.38 	LEN:  168
# ITER:  328 	RWD:  -17.82 	M_RWD:  -24.3 	LEN:  1000
# ITER:  329 	RWD:  -297.05 	M_RWD:  -26.9 	LEN:  122
# ITER:  330 	RWD:  -15.03 	M_RWD:  -26.89 	LEN:  300
# ITER:  331 	RWD:  -37.06 	M_RWD:  -26.75 	LEN:  767
# ITER:  332 	RWD:  -138.21 	M_RWD:  -27.64 	LEN:  186
# ITER:  333 	RWD:  -44.67 	M_RWD:  -27.57 	LEN:  1000
# ITER:  334 	RWD:  -362.62 	M_RWD:  -31.0 	LEN:  130
# ITER:  335 	RWD:  -43.73 	M_RWD:  -31.33 	LEN:  1000
# ITER:  336 	RWD:  -22.59 	M_RWD:  -31.77 	LEN:  1000
# ITER:  337 	RWD:  -20.03 	M_RWD:  -32.15 	LEN:  1000
# ITER:  338 	RWD:  -48.89 	M_RWD:  -32.33 	LEN:  1000
# ITER:  339 	RWD:  -85.8 	M_RWD:  -33.16 	LEN:  1000
# ITER:  340 	RWD:  -198.73 	M_RWD:  -34.63 	LEN:  1000
# ITER:  341 	RWD:  -48.24 	M_RWD:  -34.53 	LEN:  1000
# ITER:  342 	RWD:  -46.02 	M_RWD:  -34.75 	LEN:  1000
# ITER:  343 	RWD:  -198.3 	M_RWD:  -35.69 	LEN:  112
# ITER:  344 	RWD:  -161.28 	M_RWD:  -36.65 	LEN:  137
# ITER:  345 	RWD:  -51.19 	M_RWD:  -35.93 	LEN:  1000
# ITER:  346 	RWD:  -24.12 	M_RWD:  -35.68 	LEN:  1000
# ITER:  347 	RWD:  -41.66 	M_RWD:  -36.07 	LEN:  1000
# ITER:  348 	RWD:  -279.07 	M_RWD:  -38.4 	LEN:  126
# ITER:  349 	RWD:  -523.91 	M_RWD:  -43.43 	LEN:  89
# ITER:  350 	RWD:  -23.83 	M_RWD:  -43.38 	LEN:  1000
# ITER:  351 	RWD:  -219.01 	M_RWD:  -45.63 	LEN:  380
# ITER:  352 	RWD:  -372.85 	M_RWD:  -48.91 	LEN:  122
# ITER:  353 	RWD:  -317.58 	M_RWD:  -50.54 	LEN:  108
# ITER:  354 	RWD:  272.5 	M_RWD:  -47.68 	LEN:  337
# ITER:  355 	RWD:  -3.36 	M_RWD:  -47.17 	LEN:  1000
# ITER:  356 	RWD:  -63.44 	M_RWD:  -48.39 	LEN:  1000
# ITER:  357 	RWD:  -146.07 	M_RWD:  -49.6 	LEN:  1000
# ITER:  358 	RWD:  -107.19 	M_RWD:  -50.47 	LEN:  1000
# ITER:  359 	RWD:  -98.34 	M_RWD:  -50.95 	LEN:  1000
# ITER:  360 	RWD:  155.61 	M_RWD:  -49.51 	LEN:  814
# ITER:  361 	RWD:  -52.04 	M_RWD:  -49.91 	LEN:  1000
# ITER:  362 	RWD:  -254.7 	M_RWD:  -51.65 	LEN:  822
# ITER:  363 	RWD:  -252.84 	M_RWD:  -53.85 	LEN:  416
# ITER:  364 	RWD:  -263.58 	M_RWD:  -56.05 	LEN:  471
# ITER:  365 	RWD:  40.96 	M_RWD:  -53.33 	LEN:  85
# ITER:  366 	RWD:  -340.56 	M_RWD:  -56.45 	LEN:  304
# ITER:  367 	RWD:  -40.73 	M_RWD:  -56.48 	LEN:  1000
# ITER:  368 	RWD:  -38.8 	M_RWD:  -55.91 	LEN:  492
# ITER:  369 	RWD:  -246.97 	M_RWD:  -58.03 	LEN:  397
# ITER:  370 	RWD:  -175.6 	M_RWD:  -59.45 	LEN:  737
# ITER:  371 	RWD:  14.54 	M_RWD:  -59.63 	LEN:  1000
# ITER:  372 	RWD:  -488.58 	M_RWD:  -64.51 	LEN:  802
# ITER:  373 	RWD:  146.02 	M_RWD:  -62.32 	LEN:  876
# ITER:  374 	RWD:  156.36 	M_RWD:  -59.56 	LEN:  754
# ITER:  375 	RWD:  6.85 	M_RWD:  -59.38 	LEN:  1000
# ITER:  376 	RWD:  -273.31 	M_RWD:  -62.07 	LEN:  483
# ITER:  377 	RWD:  174.48 	M_RWD:  -60.1 	LEN:  928
# ITER:  378 	RWD:  134.55 	M_RWD:  -58.14 	LEN:  981
# ITER:  379 	RWD:  157.63 	M_RWD:  -56.41 	LEN:  964
# ITER:  380 	RWD:  2.33 	M_RWD:  -55.85 	LEN:  1000
# ITER:  381 	RWD:  11.28 	M_RWD:  -55.41 	LEN:  304
# ITER:  382 	RWD:  -402.68 	M_RWD:  -59.57 	LEN:  941
# ITER:  383 	RWD:  4.25 	M_RWD:  -59.2 	LEN:  1000
# ITER:  384 	RWD:  12.85 	M_RWD:  -57.95 	LEN:  1000
# ITER:  385 	RWD:  -14.99 	M_RWD:  -57.49 	LEN:  1000
# ITER:  386 	RWD:  -29.01 	M_RWD:  -57.78 	LEN:  1000
# ITER:  387 	RWD:  -20.28 	M_RWD:  -58.08 	LEN:  1000
# ITER:  388 	RWD:  -160.63 	M_RWD:  -59.47 	LEN:  411
# ITER:  389 	RWD:  -19.44 	M_RWD:  -61.04 	LEN:  1000
# ITER:  390 	RWD:  5.5 	M_RWD:  -60.15 	LEN:  1000
# ITER:  391 	RWD:  -9.83 	M_RWD:  -60.08 	LEN:  1000
# ITER:  392 	RWD:  24.32 	M_RWD:  -60.23 	LEN:  1000
# ITER:  393 	RWD:  -46.56 	M_RWD:  -60.3 	LEN:  1000
# ITER:  394 	RWD:  -25.62 	M_RWD:  -59.43 	LEN:  1000
# ITER:  395 	RWD:  -26.77 	M_RWD:  -61.68 	LEN:  1000
# ITER:  396 	RWD:  -14.65 	M_RWD:  -59.66 	LEN:  1000
# ITER:  397 	RWD:  14.15 	M_RWD:  -58.61 	LEN:  1000
# ITER:  398 	RWD:  -38.82 	M_RWD:  -58.64 	LEN:  1000
# ITER:  399 	RWD:  -8.25 	M_RWD:  -59.94 	LEN:  1000
# ITER:  400 	RWD:  -717.71 	M_RWD:  -66.69 	LEN:  242
# ITER:  401 	RWD:  -27.02 	M_RWD:  -68.77 	LEN:  1000
# ITER:  402 	RWD:  -34.34 	M_RWD:  -69.54 	LEN:  1000
# ITER:  403 	RWD:  -303.98 	M_RWD:  -73.25 	LEN:  505
# ITER:  404 	RWD:  -15.93 	M_RWD:  -72.58 	LEN:  1000
# ITER:  405 	RWD:  68.62 	M_RWD:  -71.55 	LEN:  1000
# ITER:  406 	RWD:  -9.79 	M_RWD:  -71.94 	LEN:  1000
# ITER:  407 	RWD:  -39.21 	M_RWD:  -71.89 	LEN:  1000
# ITER:  408 	RWD:  -55.48 	M_RWD:  -73.93 	LEN:  1000
# ITER:  409 	RWD:  50.12 	M_RWD:  -75.04 	LEN:  1000
# ITER:  410 	RWD:  164.74 	M_RWD:  -74.36 	LEN:  690
# ITER:  411 	RWD:  136.57 	M_RWD:  -73.43 	LEN:  836
# ITER:  412 	RWD:  9.27 	M_RWD:  -72.76 	LEN:  1000
# ITER:  413 	RWD:  -19.93 	M_RWD:  -71.95 	LEN:  1000
# ITER:  414 	RWD:  170.32 	M_RWD:  -69.95 	LEN:  990
# ITER:  415 	RWD:  35.1 	M_RWD:  -71.72 	LEN:  1000
# ITER:  416 	RWD:  -30.36 	M_RWD:  -71.36 	LEN:  1000
# ITER:  417 	RWD:  209.26 	M_RWD:  -68.24 	LEN:  684
# ITER:  418 	RWD:  163.16 	M_RWD:  -66.53 	LEN:  378
# ITER:  419 	RWD:  38.86 	M_RWD:  -65.48 	LEN:  1000
# ITER:  420 	RWD:  81.06 	M_RWD:  -64.11 	LEN:  842
# ITER:  421 	RWD:  117.06 	M_RWD:  -62.48 	LEN:  995
# ITER:  422 	RWD:  255.35 	M_RWD:  -59.29 	LEN:  301
# ITER:  423 	RWD:  255.22 	M_RWD:  -56.12 	LEN:  332
# ITER:  424 	RWD:  146.43 	M_RWD:  -53.7 	LEN:  1000
# ITER:  425 	RWD:  180.55 	M_RWD:  -50.31 	LEN:  444
# ITER:  426 	RWD:  155.83 	M_RWD:  -50.41 	LEN:  814
# ITER:  427 	RWD:  -3.87 	M_RWD:  -49.89 	LEN:  193
# ITER:  428 	RWD:  276.35 	M_RWD:  -46.95 	LEN:  521
# ITER:  429 	RWD:  -395.28 	M_RWD:  -47.93 	LEN:  311
# ITER:  430 	RWD:  201.18 	M_RWD:  -45.77 	LEN:  769
# ITER:  431 	RWD:  283.44 	M_RWD:  -42.56 	LEN:  312
# ITER:  432 	RWD:  283.09 	M_RWD:  -38.35 	LEN:  157
# ITER:  433 	RWD:  181.53 	M_RWD:  -36.09 	LEN:  334
# ITER:  434 	RWD:  250.07 	M_RWD:  -29.96 	LEN:  286
# ITER:  435 	RWD:  211.22 	M_RWD:  -27.41 	LEN:  626
# ITER:  436 	RWD:  207.28 	M_RWD:  -25.11 	LEN:  372
# ITER:  437 	RWD:  164.82 	M_RWD:  -23.26 	LEN:  553
# [INFO] ACTOR - Saving model
# [INFO] ACTOR - Saving model
# [INFO] CRITIC - Saving model
# [INFO] CRITIC - Saving model
# ITER:  438 	RWD:  256.95 	M_RWD:  -20.21 	LEN:  462
# [INFO] ACTOR - Saving model
# [INFO] ACTOR - Saving model
# [INFO] CRITIC - Saving model
# [INFO] CRITIC - Saving model
# ITER:  439 	RWD:  256.88 	M_RWD:  -16.78 	LEN:  211
# [INFO] ACTOR - Saving model
# [INFO] ACTOR - Saving model
# [INFO] CRITIC - Saving model
# [INFO] CRITIC - Saving model
# ITER:  440 	RWD:  242.72 	M_RWD:  -12.36 	LEN:  534
# [INFO] ACTOR - Saving model
# [INFO] ACTOR - Saving model
# [INFO] CRITIC - Saving model
# [INFO] CRITIC - Saving model
# ITER:  441 	RWD:  144.52 	M_RWD:  -10.44 	LEN:  706
# [INFO] ACTOR - Saving model
# [INFO] ACTOR - Saving model
# [INFO] CRITIC - Saving model
# [INFO] CRITIC - Saving model
# ITER:  442 	RWD:  180.99 	M_RWD:  -8.17 	LEN:  659
# [INFO] ACTOR - Saving model
# [INFO] ACTOR - Saving model
# [INFO] CRITIC - Saving model
# [INFO] CRITIC - Saving model
# ITER:  443 	RWD:  251.81 	M_RWD:  -3.66 	LEN:  556
# [INFO] ACTOR - Saving model
# [INFO] ACTOR - Saving model
# [INFO] CRITIC - Saving model
# [INFO] CRITIC - Saving model
# ITER:  444 	RWD:  260.01 	M_RWD:  0.55 	LEN:  178
# [INFO] ACTOR - Saving model
# [INFO] ACTOR - Saving model
# [INFO] CRITIC - Saving model
# [INFO] CRITIC - Saving model
# ITER:  445 	RWD:  216.28 	M_RWD:  3.22 	LEN:  256
# [INFO] ACTOR - Saving model
# [INFO] ACTOR - Saving model
# [INFO] CRITIC - Saving model
# [INFO] CRITIC - Saving model
# ITER:  446 	RWD:  34.59 	M_RWD:  3.81 	LEN:  172
# [INFO] ACTOR - Saving model
# [INFO] ACTOR - Saving model
# [INFO] CRITIC - Saving model
# [INFO] CRITIC - Saving model
# ITER:  447 	RWD:  301.72 	M_RWD:  7.24 	LEN:  291
# [INFO] ACTOR - Saving model
# [INFO] ACTOR - Saving model
# [INFO] CRITIC - Saving model
# [INFO] CRITIC - Saving model
# ITER:  448 	RWD:  29.29 	M_RWD:  10.33 	LEN:  1000
# [INFO] ACTOR - Saving model
# [INFO] ACTOR - Saving model
# [INFO] CRITIC - Saving model
# [INFO] CRITIC - Saving model
# ITER:  449 	RWD:  234.36 	M_RWD:  17.91 	LEN:  230
# [INFO] ACTOR - Saving model
# [INFO] ACTOR - Saving model
# [INFO] CRITIC - Saving model
# [INFO] CRITIC - Saving model
# ITER:  450 	RWD:  14.71 	M_RWD:  18.3 	LEN:  107
# [INFO] ACTOR - Saving model
# [INFO] ACTOR - Saving model
# [INFO] CRITIC - Saving model
# [INFO] CRITIC - Saving model
# ITER:  451 	RWD:  209.26 	M_RWD:  22.58 	LEN:  381
# [INFO] ACTOR - Saving model
# [INFO] ACTOR - Saving model
# [INFO] CRITIC - Saving model
# [INFO] CRITIC - Saving model
# ITER:  452 	RWD:  195.45 	M_RWD:  28.26 	LEN:  604
# [INFO] ACTOR - Saving model
# [INFO] ACTOR - Saving model
# [INFO] CRITIC - Saving model
# [INFO] CRITIC - Saving model
# ITER:  453 	RWD:  239.41 	M_RWD:  33.83 	LEN:  355
# ...
# ITER:  768 	RWD:  -131.52 	M_RWD:  178.71 	LEN:  1000
# ITER:  769 	RWD:  206.53 	M_RWD:  178.17 	LEN:  441
# ITER:  770 	RWD:  119.87 	M_RWD:  177.87 	LEN:  301
# ITER:  771 	RWD:  263.41 	M_RWD:  177.82 	LEN:  308
# ITER:  772 	RWD:  220.85 	M_RWD:  177.79 	LEN:  361
# ITER:  773 	RWD:  194.94 	M_RWD:  179.69 	LEN:  230
# ITER:  774 	RWD:  152.57 	M_RWD:  179.3 	LEN:  460
# ITER:  775 	RWD:  195.08 	M_RWD:  178.76 	LEN:  332
# ITER:  776 	RWD:  239.87 	M_RWD:  178.82 	LEN:  203
# ITER:  777 	RWD:  0.08 	M_RWD:  176.5 	LEN:  126
# ITER:  778 	RWD:  -146.95 	M_RWD:  172.41 	LEN:  407
# ITER:  779 	RWD:  -89.26 	M_RWD:  169.28 	LEN:  364
# ITER:  780 	RWD:  -231.26 	M_RWD:  168.0 	LEN:  345
# ITER:  781 	RWD:  -19.9 	M_RWD:  165.14 	LEN:  207
# ITER:  782 	RWD:  -28.0 	M_RWD:  164.67 	LEN:  150
# ITER:  783 	RWD:  143.11 	M_RWD:  166.8 	LEN:  500
# ITER:  784 	RWD:  -68.42 	M_RWD:  166.02 	LEN:  158
# ITER:  785 	RWD:  233.66 	M_RWD:  165.37 	LEN:  192
# ITER:  786 	RWD:  181.64 	M_RWD:  164.68 	LEN:  337
# ITER:  787 	RWD:  -38.34 	M_RWD:  162.3 	LEN:  370
# ITER:  788 	RWD:  -66.54 	M_RWD:  159.78 	LEN:  217
# ITER:  789 	RWD:  218.7 	M_RWD:  160.21 	LEN:  247
# ITER:  790 	RWD:  193.92 	M_RWD:  160.55 	LEN:  647
# ITER:  791 	RWD:  -51.96 	M_RWD:  160.28 	LEN:  265
# ITER:  792 	RWD:  256.54 	M_RWD:  160.4 	LEN:  282
# ITER:  793 	RWD:  163.26 	M_RWD:  159.54 	LEN:  454
# ITER:  794 	RWD:  251.55 	M_RWD:  160.44 	LEN:  855
# ITER:  795 	RWD:  -187.99 	M_RWD:  156.15 	LEN:  261
# ITER:  796 	RWD:  214.81 	M_RWD:  157.94 	LEN:  203
# ITER:  797 	RWD:  -59.69 	M_RWD:  155.23 	LEN:  351
# ITER:  798 	RWD:  -79.64 	M_RWD:  152.06 	LEN:  251
# ITER:  799 	RWD:  -168.6 	M_RWD:  148.1 	LEN:  596
# ITER:  800 	RWD:  -12.52 	M_RWD:  146.17 	LEN:  223
# ITER:  801 	RWD:  -97.12 	M_RWD:  143.05 	LEN:  234
# ITER:  802 	RWD:  223.97 	M_RWD:  145.47 	LEN:  397
# ITER:  803 	RWD:  157.12 	M_RWD:  144.18 	LEN:  417
# ITER:  804 	RWD:  219.68 	M_RWD:  143.74 	LEN:  267
# ITER:  805 	RWD:  -10.69 	M_RWD:  141.43 	LEN:  254
# ITER:  806 	RWD:  181.41 	M_RWD:  147.73 	LEN:  510
# ITER:  807 	RWD:  153.29 	M_RWD:  147.06 	LEN:  647
# ITER:  808 	RWD:  255.02 	M_RWD:  146.89 	LEN:  270
# ITER:  809 	RWD:  131.56 	M_RWD:  148.17 	LEN:  777
# ITER:  810 	RWD:  243.58 	M_RWD:  148.52 	LEN:  171
# ITER:  811 	RWD:  -339.97 	M_RWD:  142.2 	LEN:  828
# ITER:  812 	RWD:  269.43 	M_RWD:  142.34 	LEN:  176
# ITER:  813 	RWD:  241.95 	M_RWD:  144.64 	LEN:  175
# ITER:  814 	RWD:  224.49 	M_RWD:  144.52 	LEN:  228
# ITER:  815 	RWD:  144.01 	M_RWD:  143.23 	LEN:  522
# ITER:  816 	RWD:  233.0 	M_RWD:  143.25 	LEN:  162
# ITER:  817 	RWD:  204.7 	M_RWD:  142.69 	LEN:  173
# ITER:  818 	RWD:  200.88 	M_RWD:  142.12 	LEN:  171
# ITER:  819 	RWD:  226.3 	M_RWD:  141.84 	LEN:  206
# ITER:  820 	RWD:  229.92 	M_RWD:  141.97 	LEN:  332
# ITER:  821 	RWD:  188.31 	M_RWD:  141.61 	LEN:  177
# ITER:  822 	RWD:  257.04 	M_RWD:  142.0 	LEN:  197
# ITER:  823 	RWD:  -85.07 	M_RWD:  141.16 	LEN:  191
# ITER:  824 	RWD:  225.5 	M_RWD:  141.23 	LEN:  228
# ITER:  825 	RWD:  162.07 	M_RWD:  140.45 	LEN:  322
# ITER:  826 	RWD:  198.16 	M_RWD:  141.28 	LEN:  361
# ITER:  827 	RWD:  226.31 	M_RWD:  140.97 	LEN:  215
# ITER:  828 	RWD:  -85.58 	M_RWD:  137.61 	LEN:  212
# ITER:  829 	RWD:  -54.46 	M_RWD:  134.95 	LEN:  204
# ITER:  830 	RWD:  -101.83 	M_RWD:  131.79 	LEN:  334
# ITER:  831 	RWD:  133.87 	M_RWD:  130.62 	LEN:  772
# ITER:  832 	RWD:  223.48 	M_RWD:  130.36 	LEN:  420
# ITER:  833 	RWD:  235.43 	M_RWD:  132.38 	LEN:  182
# ITER:  834 	RWD:  182.37 	M_RWD:  131.66 	LEN:  737
# ITER:  835 	RWD:  158.88 	M_RWD:  130.56 	LEN:  583
# ITER:  836 	RWD:  218.66 	M_RWD:  130.27 	LEN:  670
# ITER:  837 	RWD:  258.26 	M_RWD:  130.04 	LEN:  608
# ITER:  838 	RWD:  267.7 	M_RWD:  130.26 	LEN:  221
# ITER:  839 	RWD:  212.53 	M_RWD:  131.11 	LEN:  729
# ITER:  840 	RWD:  217.6 	M_RWD:  130.86 	LEN:  749
# ITER:  841 	RWD:  229.52 	M_RWD:  134.87 	LEN:  492
# ITER:  842 	RWD:  -80.77 	M_RWD:  131.34 	LEN:  1000
# ITER:  843 	RWD:  -19.75 	M_RWD:  128.38 	LEN:  253
# ITER:  844 	RWD:  235.5 	M_RWD:  128.13 	LEN:  837
# ITER:  845 	RWD:  287.85 	M_RWD:  132.65 	LEN:  234
# ITER:  846 	RWD:  251.29 	M_RWD:  135.01 	LEN:  609
# ITER:  847 	RWD:  141.36 	M_RWD:  134.02 	LEN:  749
# ITER:  848 	RWD:  -139.3 	M_RWD:  130.19 	LEN:  441
# ITER:  849 	RWD:  -2.67 	M_RWD:  128.16 	LEN:  99
# ITER:  850 	RWD:  182.8 	M_RWD:  128.12 	LEN:  561
# ITER:  851 	RWD:  228.8 	M_RWD:  130.56 	LEN:  615
# ITER:  852 	RWD:  12.25 	M_RWD:  127.96 	LEN:  248
# ITER:  853 	RWD:  197.17 	M_RWD:  127.68 	LEN:  288
# ITER:  854 	RWD:  246.27 	M_RWD:  127.41 	LEN:  257
# ITER:  855 	RWD:  300.52 	M_RWD:  128.53 	LEN:  168
# ITER:  856 	RWD:  310.95 	M_RWD:  128.83 	LEN:  206
# ITER:  857 	RWD:  227.22 	M_RWD:  129.05 	LEN:  336
# ITER:  858 	RWD:  190.4 	M_RWD:  128.37 	LEN:  273
# ITER:  859 	RWD:  241.5 	M_RWD:  128.31 	LEN:  446
# ITER:  860 	RWD:  187.21 	M_RWD:  127.79 	LEN:  521
# ITER:  861 	RWD:  159.55 	M_RWD:  126.69 	LEN:  259
# ITER:  862 	RWD:  243.63 	M_RWD:  126.52 	LEN:  339
# ITER:  863 	RWD:  170.02 	M_RWD:  126.67 	LEN:  427
# ITER:  864 	RWD:  165.02 	M_RWD:  126.47 	LEN:  431
# ITER:  865 	RWD:  -29.3 	M_RWD:  126.54 	LEN:  284
# ITER:  866 	RWD:  251.44 	M_RWD:  126.61 	LEN:  298
# ITER:  867 	RWD:  205.24 	M_RWD:  125.95 	LEN:  513
# ITER:  868 	RWD:  271.83 	M_RWD:  129.99 	LEN:  199
# ITER:  869 	RWD:  6.07 	M_RWD:  127.98 	LEN:  129
# ITER:  870 	RWD:  227.91 	M_RWD:  129.06 	LEN:  546
# ITER:  871 	RWD:  229.63 	M_RWD:  128.72 	LEN:  234
# ITER:  872 	RWD:  21.98 	M_RWD:  126.74 	LEN:  145
# ITER:  873 	RWD:  213.26 	M_RWD:  126.92 	LEN:  253
# ITER:  874 	RWD:  240.1 	M_RWD:  127.79 	LEN:  369
# ITER:  875 	RWD:  216.94 	M_RWD:  128.01 	LEN:  388
# ITER:  876 	RWD:  270.1 	M_RWD:  128.32 	LEN:  266
# ITER:  877 	RWD:  257.52 	M_RWD:  130.89 	LEN:  838
# ITER:  878 	RWD:  251.39 	M_RWD:  134.87 	LEN:  224
# ITER:  879 	RWD:  295.54 	M_RWD:  138.72 	LEN:  205
# ITER:  880 	RWD:  232.99 	M_RWD:  143.36 	LEN:  194
# ITER:  881 	RWD:  276.36 	M_RWD:  146.33 	LEN:  204
# ITER:  882 	RWD:  248.91 	M_RWD:  149.1 	LEN:  472
# ITER:  883 	RWD:  226.83 	M_RWD:  149.93 	LEN:  219
# ITER:  884 	RWD:  264.64 	M_RWD:  153.26 	LEN:  218
# ITER:  885 	RWD:  235.3 	M_RWD:  153.28 	LEN:  214
# ITER:  886 	RWD:  267.2 	M_RWD:  154.14 	LEN:  349
# ITER:  887 	RWD:  243.49 	M_RWD:  156.95 	LEN:  192
# ITER:  888 	RWD:  -369.62 	M_RWD:  153.92 	LEN:  186
# ITER:  889 	RWD:  242.28 	M_RWD:  154.16 	LEN:  198
# ITER:  890 	RWD:  219.4 	M_RWD:  154.41 	LEN:  226
# ITER:  891 	RWD:  254.99 	M_RWD:  157.48 	LEN:  180
# ITER:  892 	RWD:  257.9 	M_RWD:  157.5 	LEN:  560
# ITER:  893 	RWD:  274.82 	M_RWD:  158.61 	LEN:  441
# ITER:  894 	RWD:  270.93 	M_RWD:  158.81 	LEN:  184
# ITER:  895 	RWD:  244.6 	M_RWD:  163.13 	LEN:  212
# ITER:  896 	RWD:  305.47 	M_RWD:  164.04 	LEN:  157
# ITER:  897 	RWD:  268.06 	M_RWD:  167.32 	LEN:  222
# ITER:  898 	RWD:  214.04 	M_RWD:  170.25 	LEN:  261
# ITER:  899 	RWD:  265.88 	M_RWD:  174.6 	LEN:  206
# ITER:  900 	RWD:  229.93 	M_RWD:  177.02 	LEN:  400
# ITER:  901 	RWD:  285.36 	M_RWD:  180.85 	LEN:  248
# ITER:  902 	RWD:  238.56 	M_RWD:  180.99 	LEN:  224
# ITER:  903 	RWD:  245.27 	M_RWD:  181.87 	LEN:  227
# ITER:  904 	RWD:  226.91 	M_RWD:  181.95 	LEN:  264
# ITER:  905 	RWD:  238.08 	M_RWD:  184.43 	LEN:  236
# ITER:  906 	RWD:  252.34 	M_RWD:  185.14 	LEN:  196
# ITER:  907 	RWD:  261.52 	M_RWD:  186.23 	LEN:  202
# ITER:  908 	RWD:  62.5 	M_RWD:  184.3 	LEN:  1000
# ITER:  909 	RWD:  273.27 	M_RWD:  185.72 	LEN:  224
# ITER:  910 	RWD:  264.55 	M_RWD:  185.93 	LEN:  238
# ITER:  911 	RWD:  190.01 	M_RWD:  191.23 	LEN:  289
# ITER:  912 	RWD:  261.99 	M_RWD:  191.15 	LEN:  278
# ITER:  913 	RWD:  272.37 	M_RWD:  191.46 	LEN:  294
# ITER:  914 	RWD:  291.19 	M_RWD:  192.12 	LEN:  221
# [INFO] ACTOR - Saving model
# [INFO] ACTOR - Saving model
# [INFO] CRITIC - Saving model
# [INFO] CRITIC - Saving model
# ITER:  915 	RWD:  293.49 	M_RWD:  193.62 	LEN:  210
# [INFO] ACTOR - Saving model
# [INFO] ACTOR - Saving model
# [INFO] CRITIC - Saving model
# [INFO] CRITIC - Saving model
# ITER:  916 	RWD:  239.47 	M_RWD:  193.68 	LEN:  376
# [INFO] ACTOR - Saving model
# [INFO] ACTOR - Saving model
# [INFO] CRITIC - Saving model
# [INFO] CRITIC - Saving model
# ITER:  917 	RWD:  268.92 	M_RWD:  194.33 	LEN:  234
# [INFO] ACTOR - Saving model
# [INFO] ACTOR - Saving model
# [INFO] CRITIC - Saving model
# [INFO] CRITIC - Saving model
# ITER:  918 	RWD:  239.37 	M_RWD:  194.71 	LEN:  288
# [INFO] ACTOR - Saving model
# [INFO] ACTOR - Saving model
# [INFO] CRITIC - Saving model
# [INFO] CRITIC - Saving model
# ITER:  919 	RWD:  263.59 	M_RWD:  195.08 	LEN:  171
# ITER:  920 	RWD:  -487.47 	M_RWD:  187.91 	LEN:  98
# ITER:  921 	RWD:  277.19 	M_RWD:  188.8 	LEN:  288
# ITER:  922 	RWD:  277.18 	M_RWD:  189.0 	LEN:  292
# ITER:  923 	RWD:  260.43 	M_RWD:  192.45 	LEN:  175
# ITER:  924 	RWD:  277.85 	M_RWD:  192.98 	LEN:  189
# ITER:  925 	RWD:  268.87 	M_RWD:  194.05 	LEN:  331
# ITER:  926 	RWD:  241.43 	M_RWD:  194.48 	LEN:  305
# ITER:  927 	RWD:  254.05 	M_RWD:  194.76 	LEN:  410
# [INFO] ACTOR - Saving model
# [INFO] ACTOR - Saving model
# [INFO] CRITIC - Saving model
# [INFO] CRITIC - Saving model
# ITER:  928 	RWD:  251.38 	M_RWD:  198.13 	LEN:  145
# [INFO] ACTOR - Saving model
# [INFO] ACTOR - Saving model
# [INFO] CRITIC - Saving model
# [INFO] CRITIC - Saving model
# ITER:  929 	RWD:  266.74 	M_RWD:  201.34 	LEN:  425
# [INFO] ACTOR - Saving model
# [INFO] ACTOR - Saving model
# [INFO] CRITIC - Saving model
# [INFO] CRITIC - Saving model
# ITER:  930 	RWD:  247.44 	M_RWD:  204.83 	LEN:  246
# [INFO] ACTOR - Saving model
# [INFO] ACTOR - Saving model
# [INFO] CRITIC - Saving model
# [INFO] CRITIC - Saving model
# ITER:  931 	RWD:  265.07 	M_RWD:  206.14 	LEN:  212
# [INFO] ACTOR - Saving model
# [INFO] ACTOR - Saving model
# [INFO] CRITIC - Saving model
# [INFO] CRITIC - Saving model
# ITER:  932 	RWD:  235.11 	M_RWD:  206.26 	LEN:  185
# ITER:  933 	RWD:  -257.01 	M_RWD:  201.33 	LEN:  131
# ITER:  934 	RWD:  -271.11 	M_RWD:  196.8 	LEN:  114
# ITER:  935 	RWD:  -283.12 	M_RWD:  192.38 	LEN:  140
# ITER:  936 	RWD:  268.38 	M_RWD:  192.88 	LEN:  141
# ITER:  937 	RWD:  249.86 	M_RWD:  192.79 	LEN:  179
# ITER:  938 	RWD:  257.85 	M_RWD:  192.69 	LEN:  323
# ITER:  939 	RWD:  258.12 	M_RWD:  193.15 	LEN:  177
# ITER:  940 	RWD:  272.75 	M_RWD:  193.7 	LEN:  156
# ITER:  941 	RWD:  276.09 	M_RWD:  194.17 	LEN:  318
# ITER:  942 	RWD:  252.37 	M_RWD:  197.5 	LEN:  363
# ITER:  943 	RWD:  251.5 	M_RWD:  200.21 	LEN:  299
# ITER:  944 	RWD:  273.73 	M_RWD:  200.59 	LEN:  192
# ITER:  945 	RWD:  262.94 	M_RWD:  200.34 	LEN:  443
# ITER:  946 	RWD:  271.23 	M_RWD:  200.54 	LEN:  258
# ITER:  947 	RWD:  276.9 	M_RWD:  201.9 	LEN:  307
# ITER:  948 	RWD:  264.44 	M_RWD:  205.94 	LEN:  216
# [INFO] ACTOR - Saving model
# [INFO] ACTOR - Saving model
# [INFO] CRITIC - Saving model
# [INFO] CRITIC - Saving model
# ITER:  949 	RWD:  260.0 	M_RWD:  208.56 	LEN:  168
# [INFO] ACTOR - Saving model
# [INFO] ACTOR - Saving model
# [INFO] CRITIC - Saving model
# [INFO] CRITIC - Saving model
# ITER:  950 	RWD:  267.01 	M_RWD:  209.41 	LEN:  271
# [INFO] ACTOR - Saving model
# [INFO] ACTOR - Saving model
# [INFO] CRITIC - Saving model
# [INFO] CRITIC - Saving model
# ITER:  951 	RWD:  271.98 	M_RWD:  209.84 	LEN:  305
# [INFO] ACTOR - Saving model
# [INFO] ACTOR - Saving model
# [INFO] CRITIC - Saving model
# [INFO] CRITIC - Saving model
# ITER:  952 	RWD:  234.74 	M_RWD:  212.06 	LEN:  215
# [INFO] ACTOR - Saving model
# [INFO] ACTOR - Saving model
# [INFO] CRITIC - Saving model
# [INFO] CRITIC - Saving model
# ITER:  953 	RWD:  288.74 	M_RWD:  212.98 	LEN:  253
# [INFO] ACTOR - Saving model
# [INFO] ACTOR - Saving model
# [INFO] CRITIC - Saving model
# [INFO] CRITIC - Saving model
# ITER:  954 	RWD:  264.13 	M_RWD:  213.16 	LEN:  225
# [INFO] ACTOR - Saving model
# [INFO] ACTOR - Saving model
# [INFO] CRITIC - Saving model
# [INFO] CRITIC - Saving model
# ITER:  955 	RWD:  301.41 	M_RWD:  213.17 	LEN:  216
# ITER:  956 	RWD:  284.63 	M_RWD:  212.9 	LEN:  235
# ITER:  957 	RWD:  159.75 	M_RWD:  212.23 	LEN:  447
# [INFO] ACTOR - Saving model
# [INFO] ACTOR - Saving model
# [INFO] CRITIC - Saving model
# [INFO] CRITIC - Saving model
# ITER:  958 	RWD:  286.22 	M_RWD:  213.19 	LEN:  189
# [INFO] ACTOR - Saving model
# [INFO] ACTOR - Saving model
# [INFO] CRITIC - Saving model
# [INFO] CRITIC - Saving model
# ITER:  959 	RWD:  280.77 	M_RWD:  213.58 	LEN:  170
# [INFO] ACTOR - Saving model
# [INFO] ACTOR - Saving model
# [INFO] CRITIC - Saving model
# [INFO] CRITIC - Saving model
# ITER:  960 	RWD:  281.86 	M_RWD:  214.52 	LEN:  187
# ITER:  961 	RWD:  -67.6 	M_RWD:  212.25 	LEN:  131
# ITER:  962 	RWD:  256.82 	M_RWD:  212.39 	LEN:  199
# ITER:  963 	RWD:  230.03 	M_RWD:  212.99 	LEN:  207
# ITER:  964 	RWD:  292.01 	M_RWD:  214.26 	LEN:  242
# [INFO] ACTOR - Saving model
# [INFO] ACTOR - Saving model
# [INFO] CRITIC - Saving model
# [INFO] CRITIC - Saving model
# ITER:  965 	RWD:  285.64 	M_RWD:  217.4 	LEN:  188
# [INFO] ACTOR - Saving model
# [INFO] ACTOR - Saving model
# [INFO] CRITIC - Saving model
# [INFO] CRITIC - Saving model
# ITER:  966 	RWD:  283.7 	M_RWD:  217.73 	LEN:  168
# [INFO] ACTOR - Saving model
# [INFO] ACTOR - Saving model
# [INFO] CRITIC - Saving model
# [INFO] CRITIC - Saving model
# ITER:  967 	RWD:  241.78 	M_RWD:  218.09 	LEN:  174
# ITER:  968 	RWD:  263.65 	M_RWD:  218.01 	LEN:  233
# [INFO] ACTOR - Saving model
# [INFO] ACTOR - Saving model
# [INFO] CRITIC - Saving model
# [INFO] CRITIC - Saving model
# ITER:  969 	RWD:  310.25 	M_RWD:  221.05 	LEN:  288
# [INFO] ACTOR - Saving model
# [INFO] ACTOR - Saving model
# [INFO] CRITIC - Saving model
# [INFO] CRITIC - Saving model
# ITER:  970 	RWD:  253.21 	M_RWD:  221.31 	LEN:  211
# [INFO] ACTOR - Saving model
# [INFO] ACTOR - Saving model
# [INFO] CRITIC - Saving model
# [INFO] CRITIC - Saving model
# ITER:  971 	RWD:  262.71 	M_RWD:  221.64 	LEN:  243
# [INFO] ACTOR - Saving model
# [INFO] ACTOR - Saving model
# [INFO] CRITIC - Saving model
# [INFO] CRITIC - Saving model
# ITER:  972 	RWD:  270.12 	M_RWD:  224.12 	LEN:  216
# [INFO] ACTOR - Saving model
# [INFO] ACTOR - Saving model
# [INFO] CRITIC - Saving model
# [INFO] CRITIC - Saving model
# ITER:  973 	RWD:  264.2 	M_RWD:  224.63 	LEN:  153
# [INFO] ACTOR - Saving model
# [INFO] ACTOR - Saving model
# [INFO] CRITIC - Saving model
# [INFO] CRITIC - Saving model
# ITER:  974 	RWD:  294.72 	M_RWD:  225.17 	LEN:  383
# [INFO] ACTOR - Saving model
# [INFO] ACTOR - Saving model
# [INFO] CRITIC - Saving model
# [INFO] CRITIC - Saving model
# ITER:  975 	RWD:  277.36 	M_RWD:  225.78 	LEN:  187
# [INFO] ACTOR - Saving model
# [INFO] ACTOR - Saving model
# [INFO] CRITIC - Saving model
# [INFO] CRITIC - Saving model
# ITER:  976 	RWD:  313.2 	M_RWD:  226.21 	LEN:  270
# ITER:  977 	RWD:  253.2 	M_RWD:  226.17 	LEN:  366
# [INFO] ACTOR - Saving model
# [INFO] ACTOR - Saving model
# [INFO] CRITIC - Saving model
# [INFO] CRITIC - Saving model
# ITER:  978 	RWD:  303.47 	M_RWD:  226.69 	LEN:  258
# ITER:  979 	RWD:  243.47 	M_RWD:  226.17 	LEN:  158
# ITER:  980 	RWD:  282.9 	M_RWD:  226.66 	LEN:  344
# ITER:  981 	RWD:  276.43 	M_RWD:  226.67 	LEN:  158
# [INFO] ACTOR - Saving model
# [INFO] ACTOR - Saving model
# [INFO] CRITIC - Saving model
# [INFO] CRITIC - Saving model
# ITER:  982 	RWD:  277.42 	M_RWD:  226.95 	LEN:  166
# ITER:  983 	RWD:  222.05 	M_RWD:  226.9 	LEN:  189
# ITER:  984 	RWD:  62.79 	M_RWD:  224.88 	LEN:  107
# ITER:  985 	RWD:  308.92 	M_RWD:  225.62 	LEN:  234
# ITER:  986 	RWD:  252.14 	M_RWD:  225.47 	LEN:  185
# ITER:  987 	RWD:  298.61 	M_RWD:  226.02 	LEN:  298
# [INFO] ACTOR - Saving model
# [INFO] ACTOR - Saving model
# [INFO] CRITIC - Saving model
# [INFO] CRITIC - Saving model
# ITER:  988 	RWD:  273.96 	M_RWD:  232.46 	LEN:  180
# [INFO] ACTOR - Saving model
# [INFO] ACTOR - Saving model
# [INFO] CRITIC - Saving model
# [INFO] CRITIC - Saving model
# ITER:  989 	RWD:  263.17 	M_RWD:  232.67 	LEN:  157
# ITER:  990 	RWD:  34.31 	M_RWD:  230.81 	LEN:  131
# ITER:  991 	RWD:  235.22 	M_RWD:  230.62 	LEN:  191
# ITER:  992 	RWD:  245.45 	M_RWD:  230.49 	LEN:  213
# ITER:  993 	RWD:  267.77 	M_RWD:  230.42 	LEN:  142
# ITER:  994 	RWD:  247.85 	M_RWD:  230.19 	LEN:  207
# ITER:  995 	RWD:  61.66 	M_RWD:  228.36 	LEN:  190
# ITER:  996 	RWD:  299.1 	M_RWD:  228.3 	LEN:  195
# ITER:  997 	RWD:  240.66 	M_RWD:  228.02 	LEN:  706
# ITER:  998 	RWD:  44.59 	M_RWD:  226.33 	LEN:  115
# ITER:  999 	RWD:  265.86 	M_RWD:  226.33 	LEN:  186

# %%
plt.plot(mean_rewards)

# %% [markdown]
# ## **Testing**

# %%
# env_name = "LunarLanderContinuous-v2"
# env = gym.make(env_name)

# agent = DDPGAgent(observation_shape=env.observation_space.shape,
#                   n_actions=env.action_space.shape[0],
#                   actor_lr=1e-4,
#                   critic_lr=1e-3,
#                   fc1_size=400,
#                   fc2_size=300,
#                   tau=0.001,
#                   gamma=0.99,
#                   mem_size=1,
#                   batch_size=1,
#                   algo_name='DDPG',
#                   env_name=env_name,
#                   model_dir='./')

# %%
#model.eval()
# with T.no_grad():
#     total_reward, total_moves = 0,0
#     done = False
#     observation = env.reset()

#     while not done:
#         time.sleep(0.0001)
#         env.render()

#         # e_GREEDY ACTION
#         action = agent.get_action(observation)
#         observation_, reward, done, _ = env.step(action)

#         total_reward += reward
#         total_moves += 1

#         observation = observation_
#     print("RWD: ",total_reward,"\tLEN: ",total_moves)
#     env.close()
